# %% [markdown]
# # Gesture Recognition
#
# In this project, you are going to build a 3D Conv model that will be able to predict the 5 gestures correctly. Please import the following libraries to get started.

# %%
import numpy as np
import os
import imageio
from skimage.transform import resize, rescale
import datetime
import os

import matplotlib.pyplot as plt

from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, GRU, LSTM, Flatten, TimeDistributed, Flatten, BatchNormalization, Activation
from keras.layers.convolutional import Conv3D, MaxPooling3D, Conv2D, MaxPooling2D
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.regularizers import l2
from keras import optimizers

# %% [markdown]
# We set the random seed so that the results don't vary drastically.

# %%
import tensorflow as tf
print(tf.__version__)
np.random.seed(30)
import random as rn
rn.seed(30)
from keras import backend as K
tf.random.set_seed(30)
# Out:
# 2.7.0

# %% [markdown]
# In this block, you read the folder names for training and validation. You also set the `batch_size` here. Note that you set the batch size in such a way that you are able to use the GPU in full capacity. You keep increasing the batch size until the machine throws an error.

# %%
train_doc = np.random.permutation(open('/home/datasets/Project_data/train.csv').readlines())
val_doc = np.random.permutation(open('/home/datasets/Project_data/val.csv').readlines())
num_classes = 5  #number of softmax classes

# %%
curr_dt_time = datetime.datetime.now()
train_path = '/home/datasets/Project_data/train'
val_path = '/home/datasets/Project_data/val'
num_train_sequences = len(train_doc)
print('# training sequences =', num_train_sequences)
num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)
# Out:
# # training sequences = 663
# # validation sequences = 100

# %% [markdown]
# ## Common Utils

# %% [markdown]
# Common utility to plot loss and accuracy

# %%
def plot_loss_accuracy(history):
    # list all data in history
    print(history.history.keys())
    # summarize history for accuracy
    plt.plot(history.history['categorical_accuracy'])
    plt.plot(history.history['val_categorical_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    # summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

# %% [markdown]
# Common utility to calculate steps

# %%
def calculate_steps(num_train_sequences, num_val_sequences, batch_size):
    if (num_train_sequences%batch_size) == 0:
        steps_per_epoch = int(num_train_sequences/batch_size)
    else:
        steps_per_epoch = (num_train_sequences//batch_size) + 1

    if (num_val_sequences%batch_size) == 0:
        validation_steps = int(num_val_sequences/batch_size)
    else:
        validation_steps = (num_val_sequences//batch_size) + 1

    return steps_per_epoch,validation_steps

# %% [markdown]
# Common utility for callbacks

# %%
def model_callbacks(folder_name):
    model_name = str(folder_name) + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
   
    if not os.path.exists(model_name):
        os.mkdir(model_name)

    filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

    checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)

    LR = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, min_lr=0.0001, cooldown=1, verbose=1) # write the REducelronplateau code here

    return [checkpoint, LR]

# %% [markdown]
# ## Generator
# This is one of the most important part of the code. The overall structure of the generator has been given. In the generator, you are going to preprocess the images as you have images of 2 different dimensions as well as create a batch of video frames. You have to experiment with `img_idx`, `y`,`z` and normalization such that you get high accuracy.

# %%
from keras.preprocessing.image import ImageDataGenerator
#from keras.preprocessing.image import smart_resize

datagen = ImageDataGenerator(
    zoom_range=0.1,
    zca_whitening=True,
    width_shift_range=0.1,
    height_shift_range=0.1)

## Test code start
#360 by 360
image1 = imageio.imread("/home/datasets/Project_data/val/WIN_20180907_15_30_06_Pro_Right Swipe_new/WIN_20180907_15_30_06_Pro_00029.png")
#160 by 120
image2 = imageio.imread("/home/datasets/Project_data/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00029.png")
#crop the images and resize them. Note that the images are of 2 different shape 
#and the conv3D will throw error if the inputs in a batch have different shapes                    
#print(image1.shape, image2.shape)
image1 = resize(image1, (120, 120), anti_aliasing=True)
image1 = datagen.random_transform(image1)                   
plt.imshow(image1)
plt.show()
image2 = resize(image2, (120, 120), anti_aliasing=True)
image2 = datagen.random_transform(image2)                 
plt.imshow(image2)
plt.show()
## Test code end

def generate(source_path, folder_list, batch_size, num_images=20, height=120, width=120, augment=False):
    #print( 'Source path = ', source_path, '; batch size =', batch_size)
    total_frames = 30

    while True:
        t = np.random.permutation(folder_list)
        num_batches = len(t)//batch_size # calculate the number of batches
        #img_idx = sorted(rn.sample(range(0, total_frames), num_images)) #create a list of image numbers you want to use for a particular video
        img_idx = np.round(np.linspace(0,total_frames-1,num_images)).astype(int) #create a list of image numbers you want to use for a particular video

        for batch in range(num_batches): # we iterate over the number of batches
            batch_data   = np.zeros((batch_size, num_images, height, width, 3)) # 3 is the number of channels RGB
            batch_labels = np.zeros((batch_size, 5)) # batch_labels is the one hot representation of the output           

            for folder in range(batch_size): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate over the frames/images of a folder to read them in
                    image = imageio.imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)

                    #crop the images and resize them. Note that the images are of 2 different shape 
                    #and the conv3D will throw error if the inputs in a batch have different shapes                    
                    h, w, c = image.shape
                    image = resize(image, (height, width), anti_aliasing=True)

                    # Randomly transform few images of few folders; note that folders are randomly shuffled in each epoch too
                    if augment:
                        if np.random.randn() > 0:
                            image = datagen.random_transform(image)                   

                    batch_data[folder,idx,:,:,0] = (image[...,0])/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,1] = (image[...,1])/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,2] = (image[...,2])/255 #normalise and feed in the image                  
                    
                batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1

            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do
        
        # write the code for the remaining data points which are left after full batches
        if (len(t)%batch_size):
            remaining_batch_size = len(t)%batch_size
            batch_data   = np.zeros((remaining_batch_size, num_images, height, width,3)) # 3 is the number of channels RGB
            batch_labels = np.zeros((remaining_batch_size,5)) # batch_labels is the one hot representation of the output           

            for folder in range(remaining_batch_size): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (num_batches*batch_size)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = imageio.imread(source_path+'/'+ t[folder + (num_batches*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                
                    #crop the images and resize them. Note that the images are of 2 different shape 
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    h, w, c = image.shape
                    image = resize(image, (height, width), anti_aliasing=True)                          
                    
                    # Randomly transform few images of few folders; note that folders are randomly shuffled in each epoch too
                    if augment:
                        if np.random.randn() > 0:
                            image = datagen.random_transform(image)                   

                    batch_data[folder,idx,:,:,0] = (image[...,0])/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,1] = (image[...,1])/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,2] = (image[...,2])/255 #normalise and feed in the image
                   
                batch_labels[folder, int(t[folder + (num_batches*batch_size)].strip().split(';')[2])] = 1

            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do
# Out:
# /usr/local/lib/python3.8/dist-packages/keras_preprocessing/image/image_data_generator.py:337: UserWarning: This ImageDataGenerator specifies `zca_whitening`, which overrides setting of `featurewise_center`.
#   warnings.warn('This ImageDataGenerator specifies '

# %% [markdown]
# Note here that a video is represented above in the generator as (number of images, height, width, number of channels). Take this into consideration while creating the model architecture.

# %% [markdown]
# ## Model
# Here you make the model using different functionalities that Keras provides. Remember to use `Conv3D` and `MaxPooling3D` and not `Conv2D` and `Maxpooling2D` for a 3D convolution model. You would want to use `TimeDistributed` while building a Conv2D + RNN model. Also remember that the last layer is the softmax. Design the network in such a way that the model is able to give good accuracy on the least number of parameters so that it can fit in the memory of the webcam.

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, GRU, LSTM, Flatten, TimeDistributed, Flatten, BatchNormalization, Activation
from keras.layers.convolutional import Conv3D, MaxPooling3D, Conv2D, MaxPooling2D
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.regularizers import l2
from keras import optimizers

# %% [markdown]
# ### Conv3d Models

# %%
# Common utility to create conv 3D models
def conv3D(conv_filters=(16, 32, 64, 128), dense_nodes=(256,128), dropout=0.25, num_images=20, height=120, width=120):

    model = Sequential()

    model.add(Conv3D(conv_filters[0], (3, 3, 3), padding='same', input_shape=(num_images, height, width, 3)))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling3D(pool_size=(2, 2, 2)))

    model.add(Conv3D(conv_filters[1], (3, 3, 3), padding='same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling3D(pool_size=(2, 2, 2)))
    
    model.add(Conv3D(conv_filters[2], (3, 3, 3), padding='same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling3D(pool_size=(2, 2, 2)))
    
    model.add(Conv3D(conv_filters[3], (3, 3, 3), padding='same'))    
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling3D(pool_size=(2, 2, 2)))
    
    model.add(Flatten())
    model.add(Dense(dense_nodes[0]))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(Dropout(dropout))

    model.add(Dense(dense_nodes[1]))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(Dropout(dropout))

    model.add(Dense(num_classes))
    model.add(Activation('softmax'))

    opt = tf.keras.optimizers.Adam() #write your optimizer
    model.compile(opt, loss='categorical_crossentropy', metrics=['categorical_accuracy'])    
    
    return model

# %% [markdown]
# #### Model 1: Conv 3D Model with 30 frames per video (16, 32, 64, 128 filters conv 3D layers + 256 dense layer + 128 dense layer + image size 120 by 120)

# %%
num_epochs = 20 # choose the number of epochs
print ('# epochs =', num_epochs)
batch_size = 10  #experiment with the batch size
print ('# batch size =', batch_size)
num_frames = 30
print ('# num_frames per video =', num_frames)
height = 120
width = 120

model = conv3D(num_images=num_frames)

print (model.summary())
# Out:
# # epochs = 25
# # batch size = 10
# # num_frames per video = 30
# 2023-08-29 07:28:41.805433: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2023-08-29 07:28:41.805495: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14796 MB memory:  -> device: 0, name: Quadro RTX 5000, pci bus id: 0000:1c:00.0, compute capability: 7.5
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d (Conv3D)             (None, 30, 120, 120, 16)  1312
#
#  activation (Activation)     (None, 30, 120, 120, 16)  0
#
#  batch_normalization (BatchN  (None, 30, 120, 120, 16)  64
#  ormalization)
#
#  max_pooling3d (MaxPooling3D  (None, 15, 60, 60, 16)   0
#  )
#
#  conv3d_1 (Conv3D)           (None, 15, 60, 60, 32)    13856
#
#  activation_1 (Activation)   (None, 15, 60, 60, 32)    0
#
#  batch_normalization_1 (Batc  (None, 15, 60, 60, 32)   128
#  hNormalization)
#
#  max_pooling3d_1 (MaxPooling  (None, 7, 30, 30, 32)    0
#  3D)
#
#  conv3d_2 (Conv3D)           (None, 7, 30, 30, 64)     55360
#
#  activation_2 (Activation)   (None, 7, 30, 30, 64)     0
#
#  batch_normalization_2 (Batc  (None, 7, 30, 30, 64)    256
#  hNormalization)
#
#  max_pooling3d_2 (MaxPooling  (None, 3, 15, 15, 64)    0
#  3D)
#
#  conv3d_3 (Conv3D)           (None, 3, 15, 15, 128)    221312
#
#  activation_3 (Activation)   (None, 3, 15, 15, 128)    0
#
#  batch_normalization_3 (Batc  (None, 3, 15, 15, 128)   512
#  hNormalization)
#
#  max_pooling3d_3 (MaxPooling  (None, 1, 7, 7, 128)     0
#  3D)
#
#  flatten (Flatten)           (None, 6272)              0
#
#  dense (Dense)               (None, 256)               1605888
#
#  activation_4 (Activation)   (None, 256)               0
#
#  batch_normalization_4 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  activation_5 (Activation)   (None, 128)               0
#
#  batch_normalization_5 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 5)                 645
#
#  activation_6 (Activation)   (None, 5)                 0
#
# =================================================================
# Total params: 1,933,765
# Trainable params: 1,932,517
# Non-trainable params: 1,248
# _________________________________________________________________
# None

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit_generator` to decide the number of next() calls it need to make.
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %%
callbacks_list = model_callbacks("model_conv3D_1")

steps_per_epoch, validation_steps = calculate_steps(num_train_sequences, num_val_sequences, batch_size)

train_generator = generate(train_path, train_doc, batch_size, num_images=num_frames)

val_generator   = generate(val_path, val_doc, batch_size, num_images=num_frames)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                             callbacks=callbacks_list, validation_data=val_generator, 
                             validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Epoch 1/25
# 2023-08-28 12:47:22.561028: I tensorflow/stream_executor/cuda/cuda_dnn.cc:377] Loaded cuDNN version 8302
# 67/67 [==============================] - ETA: 0s - loss: 1.6461 - categorical_accuracy: 0.4238
# Epoch 00001: val_loss improved from inf to 5.75922, saving model to model_conv3D_1_2023-08-2812_46_28.519095/model-00001-1.64605-0.42383-5.75922-0.16000.h5
# 67/67 [==============================] - 164s 2s/step - loss: 1.6461 - categorical_accuracy: 0.4238 - val_loss: 5.7592 - val_categorical_accuracy: 0.1600 - lr: 0.0010
# Epoch 2/25
# 67/67 [==============================] - ETA: 0s - loss: 1.1180 - categorical_accuracy: 0.5445
# Epoch 00002: val_loss did not improve from 5.75922
# 67/67 [==============================] - 161s 2s/step - loss: 1.1180 - categorical_accuracy: 0.5445 - val_loss: 7.8871 - val_categorical_accuracy: 0.1900 - lr: 0.0010
# Epoch
25
# 67/67 [==============================] - ETA: 0s - loss: 0.2560 - categorical_accuracy: 0.9095
# Epoch 00015: val_loss did not improve from 0.36275
# 67/67 [==============================] - 162s 2s/step - loss: 0.2560 - categorical_accuracy: 0.9095 - val_loss: 0.5905 - val_categorical_accuracy: 0.8200 - lr: 1.0000e-04
# Epoch 16/25
# 67/67 [==============================] - ETA: 0s - loss: 0.1891 - categorical_accuracy: 0.9351
# Epoch 00016: val_loss did not improve from 0.36275
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0001.
# 67/67 [==============================] - 162s 2s/step - loss: 0.1891 - categorical_accuracy: 0.9351 - val_loss: 0.5165 - val_categorical_accuracy: 0.8200 - lr: 1.0000e-04
# Epoch 17/25
# 67/67 [==============================] - ETA: 0s - loss: 0.1616 - categorical_accuracy: 0.9457
# Epoch 00017: val_loss did not improve from 0.36275
# 67/67 [==============================] - 161s 2s/step - loss: 0.1616 - categorical_accuracy: 0.9457 - val_loss: 0.5417 - val_categorical_accuracy: 0.8100 - lr: 1.0000e-04
# Epoch 18/25
# 67/67 [==============================] - ETA: 0s - loss: 0.1425 - categorical_accuracy: 0.9532
# Epoch 00018: val_loss did not improve from 0.36275
# 67/67 [==============================] - 162s 2s/step - loss: 0.1425 - categorical_accuracy: 0.9532 - val_loss: 0.3719 - val_categorical_accuracy: 0.8400 - lr: 1.0000e-04
# Epoch 19/25
# 67/67 [==============================] - ETA: 0s - loss: 0.1410 - categorical_accuracy: 0.9593
# Epoch 00019: val_loss did not improve from 0.36275
# 67/67 [==============================] - 162s 2s/step - loss: 0.1410 - categorical_accuracy: 0.9593 - val_loss: 0.5456 - val_categorical_accuracy: 0.8500 - lr: 1.0000e-04
# Epoch 20/25
# 67/67 [==============================] - ETA: 0s - loss: 0.1812 - categorical_accuracy: 0.9412
# Epoch 00020: val_loss did not improve from 0.36275
# 67/67 [==============================] - 162s 2s/step - loss: 0.1812 - categorical_accuracy: 0.9412 - val_loss: 0.5401 - val_categorical_accuracy: 0.8400 - lr: 1.0000e-04
# Epoch 21/25
# 67/67 [==============================] - ETA: 0s - loss: 0.1193 - categorical_accuracy: 0.9638
# Epoch 00021: val_loss did not improve from 0.36275
# 67/67 [==============================] - 162s 2s/step - loss: 0.1193 - categorical_accuracy: 0.9638 - val_loss: 0.4650 - val_categorical_accuracy: 0.8400 - lr: 1.0000e-04
# Epoch 22/25
# 67/67 [==============================] - ETA: 0s - loss: 0.1077 - categorical_accuracy: 0.9698
# Epoch 00022: val_loss did not improve from 0.36275
# 67/67 [==============================] - 163s 2s/step - loss: 0.1077 - categorical_accuracy: 0.9698 - val_loss: 0.4709 - val_categorical_accuracy: 0.8400 - lr: 1.0000e-04
# Epoch 23/25
# 67/67 [==============================] - ETA: 0s - loss: 0.1621 - categorical_accuracy: 0.9502
# Epoch 00023: val_loss did not improve from 0.36275
# 67/67 [==============================] - 162s 2s/step - loss: 0.1621 - categorical_accuracy: 0.9502 - val_loss: 0.5492 - val_categorical_accuracy: 0.8400 - lr: 1.0000e-04
# Epoch 24/25
# 67/67 [==============================] - ETA: 0s - loss: 0.0890 - categorical_accuracy: 0.9774
# Epoch 00024: val_loss did not improve from 0.36275
# 67/67 [==============================] - 160s 2s/step - loss: 0.0890 - categorical_accuracy: 0.9774 - val_loss: 0.4296 - val_categorical_accuracy: 0.8600 - lr: 1.0000e-04
# Epoch 25/25
# 67/67 [==============================] - ETA: 0s - loss: 0.1099 - categorical_accuracy: 0.9638
# Epoch 00025: val_loss did not improve from 0.36275
# 67/67 [==============================] - 158s 2s/step - loss: 0.1099 - categorical_accuracy: 0.9638 - val_loss: 0.4900 - val_categorical_accuracy: 0.8300 - lr: 1.0000e-04

# %%
plot_loss_accuracy(history)
# Out:
# dict_keys(['loss', 'categorical_accuracy', 'val_loss', 'val_categorical_accuracy', 'lr'])

# %% [markdown]
# #### Model 2: Conv 3D Model with 20 frames per video (16, 32, 64, 128 filters conv 3D layers + 256 dense layer + 128 dense layer + image size 120 by 120)

# %%
num_epochs = 20 # choose the number of epochs
#print ('# epochs =', num_epochs)
batch_size = 10  #experiment with the batch size
print ('# batch size =', batch_size)
num_frames = 20
print ('# num_frames per video =', num_frames)
height = 120
width = 120

model = conv3D(num_images=num_frames)

print (model.summary())
# Out:
# # batch size = 10
# # num_frames per video = 20
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d (Conv3D)             (None, 20, 120, 120, 16)  1312
#
#  activation (Activation)     (None, 20, 120, 120, 16)  0
#
#  batch_normalization (BatchN  (None, 20, 120, 120, 16)  64
#  ormalization)
#
#  max_pooling3d (MaxPooling3D  (None, 10, 60, 60, 16)   0
#  )
#
#  conv3d_1 (Conv3D)           (None, 10, 60, 60, 32)    13856
#
#  activation_1 (Activation)   (None, 10, 60, 60, 32)    0
#
#  batch_normalization_1 (Batc  (None, 10, 60, 60, 32)   128
#  hNormalization)
#
#  max_pooling3d_1 (MaxPooling  (None, 5, 30, 30, 32)    0
#  3D)
#
#  conv3d_2 (Conv3D)           (None, 5, 30, 30, 64)     55360
#
#  activation_2 (Activation)   (None, 5, 30, 30, 64)     0
#
#  batch_normalization_2 (Batc  (None, 5, 30, 30, 64)    256
#  hNormalization)
#
#  max_pooling3d_2 (MaxPooling  (None, 2, 15, 15, 64)    0
#  3D)
#
#  conv3d_3 (Conv3D)           (None, 2, 15, 15, 128)    221312
#
#  activation_3 (Activation)   (None, 2, 15, 15, 128)    0
#
#  batch_normalization_3 (Batc  (None, 2, 15, 15, 128)   512
#  hNormalization)
#
#  max_pooling3d_3 (MaxPooling  (None, 1, 7, 7, 128)     0
#  3D)
#
#  flatten (Flatten)           (None, 6272)              0
#
#  dense (Dense)               (None, 256)               1605888
#
#  activation_4 (Activation)   (None, 256)               0
#
#  batch_normalization_4 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  activation_5 (Activation)   (None, 128)               0
#
#  batch_normalization_5 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 5)                 645
#
#  activation_6 (Activation)   (None, 5)                 0
#
# =================================================================
# Total params: 1,933,765
# Trainable params: 1,932,517
# Non-trainable params: 1,248
# _________________________________________________________________
# None
# 2023-08-29 13:41:37.456719: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2023-08-29 13:41:37.456790: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14796 MB memory:  -> device: 0, name: Quadro RTX 5000, pci bus id: 0000:40:00.0, compute capability: 7.5

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit_generator` to decide the number of next() calls it need to make.
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %%
callbacks_list = model_callbacks("model_conv3D_2")

steps_per_epoch, validation_steps = calculate_steps(num_train_sequences, num_val_sequences, batch_size)

train_generator = generate(train_path, train_doc, batch_size, num_images=num_frames)

val_generator   = generate(val_path, val_doc, batch_size, num_images=num_frames)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                              callbacks=callbacks_list, validation_data=val_generator, 
                              validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Epoch 1/20
# 2023-08-29 13:41:57.212142: I tensorflow/stream_executor/cuda/cuda_dnn.cc:377] Loaded cuDNN version 8302
#
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 67/67 [==============================] - 108s 2s/step - loss: 0.2659 - categorical_accuracy: 0.9065 - val_loss: 1.9374 - val_categorical_accuracy: 0.4600 - lr: 0.0010
# Epoch 14/20
# 67/67 [==============================] - ETA: 0s - loss: 0.1809 - categorical_accuracy: 0.9367
# Epoch 00014: val_loss improved from 0.64132 to 0.43661, saving model to model_conv3D_2_2023-08-2913_41_03.339316/model-00014-0.18093-0.93665-0.43661-0.84000.h5
# 67/67 [==============================] - 109s 2s/step - loss: 0.1809 - categorical_accuracy: 0.9367 - val_loss: 0.4366 - val_categorical_accuracy: 0.8400 - lr: 1.0000e-04
# Epoch 15/20
# 67/67 [==============================] - ETA: 0s - loss: 0.1625 - categorical_accuracy: 0.9472
# Epoch 00015: val_loss did not improve from 0.43661
# 67/67 [==============================] - 109s 2s/step - loss: 0.1625 - categorical_accuracy: 0.9472 - val_loss: 0.6711 - val_categorical_accuracy: 0.8100 - lr: 1.0000e-04
# Epoch 16/20
# 67/67 [==============================] - ETA: 0s - loss: 0.1486 - categorical_accuracy: 0.9487
# Epoch 00016: val_loss improved from 0.43661 to 0.25382, saving model to model_conv3D_2_2023-08-2913_41_03.339316/model-00016-0.14857-0.94872-0.25382-0.87000.h5
# 67/67 [==============================] - 110s 2s/step - loss: 0.1486 - categorical_accuracy: 0.9487 - val_loss: 0.2538 - val_categorical_accuracy: 0.8700 - lr: 1.0000e-04
# Epoch 17/20
# 67/67 [==============================] - ETA: 0s - loss: 0.0926 - categorical_accuracy: 0.9698
# Epoch 00017: val_loss did not improve from 0.25382
# 67/67 [==============================] - 108s 2s/step - loss: 0.0926 - categorical_accuracy: 0.9698 - val_loss: 0.2912 - val_categorical_accuracy: 0.8700 - lr: 1.0000e-04
# Epoch 18/20
# 67/67 [==============================] - ETA: 0s - loss: 0.0833 - categorical_accuracy: 0.9759
# Epoch 00018: val_loss did not improve from 0.25382
# 67/67 [==============================] - 107s 2s/step - loss: 0.0833 - categorical_accuracy: 0.9759 - val_loss: 0.3140 - val_categorical_accuracy: 0.8700 - lr: 1.0000e-04
# Epoch 19/20
# 67/67 [==============================] - ETA: 0s - loss: 0.0750 - categorical_accuracy: 0.9804
# Epoch 00019: val_loss did not improve from 0.25382
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0001.
# 67/67 [==============================] - 110s 2s/step - loss: 0.0750 - categorical_accuracy: 0.9804 - val_loss: 0.2629 - val_categorical_accuracy: 0.9100 - lr: 1.0000e-04
# Epoch 20/20
# 67/67 [==============================] - ETA: 0s - loss: 0.1071 - categorical_accuracy: 0.9698
# Epoch 00020: val_loss improved from 0.25382 to 0.24425, saving model to model_conv3D_2_2023-08-2913_41_03.339316/model-00020-0.10707-0.96983-0.24425-0.90000.h5
# 67/67 [==============================] - 109s 2s/step - loss: 0.1071 - categorical_accuracy: 0.9698 - val_loss: 0.2443 - val_categorical_accuracy: 0.9000 - lr: 1.0000e-04

# %%
plot_loss_accuracy(history)
# Out:
# dict_keys(['loss', 'categorical_accuracy', 'val_loss', 'val_categorical_accuracy', 'lr'])

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit_generator` to decide the number of next() calls it need to make.
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %% [markdown]
# #### Model 3: Conv 3D Model with 20 frames per video (16, 32, 64, 128 filters conv 3D layers + 256 dense layer + 128 dense layer + image size 160 by 160)

# %%
num_epochs = 20 # choose the number of epochs
print ('# epochs =', num_epochs)
batch_size = 10  #experiment with the batch size
print ('# batch size =', batch_size)
num_frames = 20
print ('# num_frames per video =', num_frames)
height = 160
width = 160

model = conv3D(num_images=num_frames, height=160, width=160)

print (model.summary())
# Out:
# # epochs = 20
# # batch size = 10
# # num_frames per video = 20
# 2023-08-29 16:28:46.609339: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2023-08-29 16:28:46.609397: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14796 MB memory:  -> device: 0, name: Quadro RTX 5000, pci bus id: 0000:1d:00.0, compute capability: 7.5
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d (Conv3D)             (None, 20, 160, 160, 16)  1312
#
#  activation (Activation)     (None, 20, 160, 160, 16)  0
#
#  batch_normalization (BatchN  (None, 20, 160, 160, 16)  64
#  ormalization)
#
#  max_pooling3d (MaxPooling3D  (None, 10, 80, 80, 16)   0
#  )
#
#  conv3d_1 (Conv3D)           (None, 10, 80, 80, 32)    13856
#
#  activation_1 (Activation)   (None, 10, 80, 80, 32)    0
#
#  batch_normalization_1 (Batc  (None, 10, 80, 80, 32)   128
#  hNormalization)
#
#  max_pooling3d_1 (MaxPooling  (None, 5, 40, 40, 32)    0
#  3D)
#
#  conv3d_2 (Conv3D)           (None, 5, 40, 40, 64)     55360
#
#  activation_2 (Activation)   (None, 5, 40, 40, 64)     0
#
#  batch_normalization_2 (Batc  (None, 5, 40, 40, 64)    256
#  hNormalization)
#
#  max_pooling3d_2 (MaxPooling  (None, 2, 20, 20, 64)    0
#  3D)
#
#  conv3d_3 (Conv3D)           (None, 2, 20, 20, 128)    221312
#
#  activation_3 (Activation)   (None, 2, 20, 20, 128)    0
#
#  batch_normalization_3 (Batc  (None, 2, 20, 20, 128)   512
#  hNormalization)
#
#  max_pooling3d_3 (MaxPooling  (None, 1, 10, 10, 128)   0
#  3D)
#
#  flatten (Flatten)           (None, 12800)             0
#
#  dense (Dense)               (None, 256)               3277056
#
#  activation_4 (Activation)   (None, 256)               0
#
#  batch_normalization_4 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  activation_5 (Activation)   (None, 128)               0
#
#  batch_normalization_5 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 5)                 645
#
#  activation_6 (Activation)   (None, 5)                 0
#
# =================================================================
# Total params: 3,604,933
# Trainable params: 3,603,685
# Non-trainable params: 1,248
# _________________________________________________________________
# None

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit_generator` to decide the number of next() calls it need to make.
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %%
callbacks_list = model_callbacks("model_conv3D_3")

steps_per_epoch, validation_steps = calculate_steps(num_train_sequences, num_val_sequences, batch_size)

train_generator = generate(train_path, train_doc, batch_size, num_images=num_frames, height=160, width=160)

val_generator   = generate(val_path, val_doc, batch_size, num_images=num_frames, height=160, width=160)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                              callbacks=callbacks_list, validation_data=val_generator, 
                              validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Epoch 1/20
# 2023-08-29 16:29:00.608094: I tensorflow/stream_executor/cuda/cuda_dnn.cc:377] Loaded cuDNN version 8302
# 67/67 [==============================] - ETA: 0s - loss: 1.5180 - categorical_accuracy: 0.4434
# Epoch 00001: val_loss improved from inf to 6.51329, saving model to model_conv3D_3_2023-08-2916_28_22.343912/model-
0000e-04
# Epoch 14/20
# 67/67 [==============================] - ETA: 0s - loss: 0.2176 - categorical_accuracy: 0.9201
# Epoch 00014: val_loss improved from 0.33106 to 0.30410, saving model to model_conv3D_3_2023-08-2916_28_22.343912/model-00014-0.21762-0.92006-0.30410-0.90000.h5
# 67/67 [==============================] - 116s 2s/step - loss: 0.2176 - categorical_accuracy: 0.9201 - val_loss: 0.3041 - val_categorical_accuracy: 0.9000 - lr: 1.0000e-04
# Epoch 15/20
# 67/67 [==============================] - ETA: 0s - loss: 0.2262 - categorical_accuracy: 0.9201
# Epoch 00015: val_loss did not improve from 0.30410
# 67/67 [==============================] - 116s 2s/step - loss: 0.2262 - categorical_accuracy: 0.9201 - val_loss: 0.4492 - val_categorical_accuracy: 0.8400 - lr: 1.0000e-04
# Epoch 16/20
# 67/67 [==============================] - ETA: 0s - loss: 0.1884 - categorical_accuracy: 0.9412
# Epoch 00016: val_loss did not improve from 0.30410
# 67/67 [==============================] - 118s 2s/step - loss: 0.1884 - categorical_accuracy: 0.9412 - val_loss: 0.5976 - val_categorical_accuracy: 0.7700 - lr: 1.0000e-04
# Epoch 17/20
# 67/67 [==============================] - ETA: 0s - loss: 0.1783 - categorical_accuracy: 0.9397
# Epoch 00017: val_loss did not improve from 0.30410
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.0001.
# 67/67 [==============================] - 118s 2s/step - loss: 0.1783 - categorical_accuracy: 0.9397 - val_loss: 0.3474 - val_categorical_accuracy: 0.8700 - lr: 1.0000e-04
# Epoch 18/20
# 67/67 [==============================] - ETA: 0s - loss: 0.1395 - categorical_accuracy: 0.9517
# Epoch 00018: val_loss did not improve from 0.30410
# 67/67 [==============================] - 115s 2s/step - loss: 0.1395 - categorical_accuracy: 0.9517 - val_loss: 0.3193 - val_categorical_accuracy: 0.8700 - lr: 1.0000e-04
# Epoch 19/20
# 67/67 [==============================] - ETA: 0s - loss: 0.1170 - categorical_accuracy: 0.9698
# Epoch 00019: val_loss did not improve from 0.30410
# 67/67 [==============================] - 116s 2s/step - loss: 0.1170 - categorical_accuracy: 0.9698 - val_loss: 0.3071 - val_categorical_accuracy: 0.8800 - lr: 1.0000e-04
# Epoch 20/20
# 67/67 [==============================] - ETA: 0s - loss: 0.1966 - categorical_accuracy: 0.9321
# Epoch 00020: val_loss improved from 0.30410 to 0.28305, saving model to model_conv3D_3_2023-08-2916_28_22.343912/model-00020-0.19659-0.93213-0.28305-0.91000.h5
# 67/67 [==============================] - 119s 2s/step - loss: 0.1966 - categorical_accuracy: 0.9321 - val_loss: 0.2831 - val_categorical_accuracy: 0.9100 - lr: 1.0000e-04

# %%
plot_loss_accuracy(history)
# Out:
# dict_keys(['loss', 'categorical_accuracy', 'val_loss', 'val_categorical_accuracy', 'lr'])

# %% [markdown]
# #### Conv 3D Model with 30 frames per video (16, 32, 64, 128 filters conv 3D layers + 256 dense layer + 128 dense layer) + Random data transformations on training data set

# %%
num_epochs = 15 # choose the number of epochs
print ('# epochs =', num_epochs)
batch_size = 10  #experiment with the batch size
print ('# batch size =', batch_size)
num_frames = 30
print ('# num_frames per video =', num_frames)
height = 120
width = 120

model = conv3D(num_images=num_frames)

print (model.summary())
# Out:
# # epochs = 15
# # batch size = 10
# # num_frames per video = 30
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_16 (Conv3D)          (None, 30, 120, 120, 16)  1312
#
#  activation_28 (Activation)  (None, 30, 120, 120, 16)  0
#
#  batch_normalization_24 (Bat  (None, 30, 120, 120, 16)  64
#  chNormalization)
#
#  max_pooling3d_16 (MaxPoolin  (None, 15, 60, 60, 16)   0
#  g3D)
#
#  conv3d_17 (Conv3D)          (None, 15, 60, 60, 32)    13856
#
#  activation_29 (Activation)  (None, 15, 60, 60, 32)    0
#
#  batch_normalization_25 (Bat  (None, 15, 60, 60, 32)   128
#  chNormalization)
#
#  max_pooling3d_17 (MaxPoolin  (None, 7, 30, 30, 32)    0
#  g3D)
#
#  conv3d_18 (Conv3D)          (None, 7, 30, 30, 64)     55360
#
#  activation_30 (Activation)  (None, 7, 30, 30, 64)     0
#
#  batch_normalization_26 (Bat  (None, 7, 30, 30, 64)    256
#  chNormalization)
#
#  max_pooling3d_18 (MaxPoolin  (None, 3, 15, 15, 64)    0
#  g3D)
#
#  conv3d_19 (Conv3D)          (None, 3, 15, 15, 128)    221312
#
#  activation_31 (Activation)  (None, 3, 15, 15, 128)    0
#
#  batch_normalization_27 (Bat  (None, 3, 15, 15, 128)   512
#  chNormalization)
#
#  max_pooling3d_19 (MaxPoolin  (None, 1, 7, 7, 128)     0
#  g3D)
#
#  flatten_4 (Flatten)         (None, 6272)              0
#
#  dense_12 (Dense)            (None, 256)               1605888
#
#  activation_32 (Activation)  (None, 256)               0
#
#  batch_normalization_28 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_8 (Dropout)         (None, 256)               0
#
#  dense_13 (Dense)            (None, 128)               32896
#
#  activation_33 (Activation)  (None, 128)               0
#
#  batch_normalization_29 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_9 (Dropout)         (None, 128)               0
#
#  dense_14 (Dense)            (None, 5)                 645
#
#  activation_34 (Activation)  (None, 5)                 0
#
# =================================================================
# Total params: 1,933,765
# Trainable params: 1,932,517
# Non-trainable params: 1,248
# _________________________________________________________________
# None

# %%
callbacks_list = model_callbacks("model_conv3D_4")

steps_per_epoch, validation_steps = calculate_steps(num_train_sequences, num_val_sequences, batch_size)

train_generator = generate(train_path, train_doc, batch_size, augment=True, num_images=num_frames)

val_generator   = generate(val_path, val_doc, batch_size, num_images=num_frames)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                              callbacks=callbacks_list, validation_data=val_generator, 
                              validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Epoch 1/15
# 67/67 [==============================] - ETA: 0s - loss: 1.6539 - categorical_accuracy: 0.4103
# Epoch 00001: val_loss improved from inf to 1.65786, saving model to model_conv3D_5_2023-08-2812_46_28.519095/model-00001-1.65395-0.41026-1.65786-0.26000.h5
# 67/67 [==============================] - 187s 3s/step - loss: 1.6539 - categorical_accuracy: 0.4103 - val_loss: 1.6579 - val_categorical_accuracy: 0.2600 - lr: 0.0010
# Epoch 2/15
# 67/67 [==============================] - ETA: 0s - loss: 1.2791 - categorical_accuracy: 0.5249
# Epoch 00002: val_loss did not improve from 1.65786
# 67/67 [==============================] - 183s 3s/step - loss: 1.2791 - categorical_accuracy: 0.5249 - val_loss: 4.8654 - val_categorical_accuracy: 0.1700 - lr: 0.0010
# Epoch 3/15
# 67/67 [==============================] - ETA: 0s - loss:
- val_categorical_accuracy: 0.7400 - lr: 1.0000e-04
# Epoch 15/15
# 67/67 [==============================] - ETA: 0s - loss: 0.5229 - categorical_accuracy: 0.7919
# Epoch 00015: val_loss did not improve from 0.75588
# 67/67 [==============================] - 185s 3s/step - loss: 0.5229 - categorical_accuracy: 0.7919 - val_loss: 1.0281 - val_categorical_accuracy: 0.5300 - lr: 1.0000e-04

# %%
plot_loss_accuracy(history)
# Out:
# dict_keys(['loss', 'categorical_accuracy', 'val_loss', 'val_categorical_accuracy', 'lr'])

# %% [markdown]
# #### Model 5: Conv 3D Model with 30 frames per video (8, 16, 32, 64 filters conv 3D layers + 256 dense layer + 128 dense layer + image size 120 by 120)

# %%
num_epochs = 25 # choose the number of epochs
print ('# epochs =', num_epochs)
batch_size = 10  #experiment with the batch size
print ('# batch size =', batch_size)
num_frames = 30
print ('# num_frames per video =', num_frames)
height = 120
width = 120

conv_filters = (8, 16, 32, 64) 
model = conv3D(conv_filters, num_images=num_frames)
print (model.summary())
# Out:
# # epochs = 25
# # batch size = 10
# # num_frames per video = 30
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_4 (Conv3D)           (None, 30, 120, 120, 8)   656
#
#  activation_7 (Activation)   (None, 30, 120, 120, 8)   0
#
#  batch_normalization_6 (Batc  (None, 30, 120, 120, 8)  32
#  hNormalization)
#
#  max_pooling3d_4 (MaxPooling  (None, 15, 60, 60, 8)    0
#  3D)
#
#  conv3d_5 (Conv3D)           (None, 15, 60, 60, 16)    3472
#
#  activation_8 (Activation)   (None, 15, 60, 60, 16)    0
#
#  batch_normalization_7 (Batc  (None, 15, 60, 60, 16)   64
#  hNormalization)
#
#  max_pooling3d_5 (MaxPooling  (None, 7, 30, 30, 16)    0
#  3D)
#
#  conv3d_6 (Conv3D)           (None, 7, 30, 30, 32)     13856
#
#  activation_9 (Activation)   (None, 7, 30, 30, 32)     0
#
#  batch_normalization_8 (Batc  (None, 7, 30, 30, 32)    128
#  hNormalization)
#
#  max_pooling3d_6 (MaxPooling  (None, 3, 15, 15, 32)    0
#  3D)
#
#  conv3d_7 (Conv3D)           (None, 3, 15, 15, 64)     55360
#
#  activation_10 (Activation)  (None, 3, 15, 15, 64)     0
#
#  batch_normalization_9 (Batc  (None, 3, 15, 15, 64)    256
#  hNormalization)
#
#  max_pooling3d_7 (MaxPooling  (None, 1, 7, 7, 64)      0
#  3D)
#
#  flatten_1 (Flatten)         (None, 3136)              0
#
#  dense_3 (Dense)             (None, 256)               803072
#
#  activation_11 (Activation)  (None, 256)               0
#
#  batch_normalization_10 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 128)               32896
#
#  activation_12 (Activation)  (None, 128)               0
#
#  batch_normalization_11 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 5)                 645
#
#  activation_13 (Activation)  (None, 5)                 0
#
# =================================================================
# Total params: 911,973
# Trainable params: 910,965
# Non-trainable params: 1,008
# _________________________________________________________________
# None

# %%
callbacks_list = model_callbacks("model_conv3D_5")

steps_per_epoch, validation_steps = calculate_steps(num_train_sequences, num_val_sequences, batch_size)

train_generator = generate(train_path, train_doc, batch_size, num_images=num_frames)

val_generator   = generate(val_path, val_doc, batch_size, num_images=num_frames)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                              callbacks=callbacks_list, validation_data=val_generator, 
                              validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Epoch 1/25
# 2023-08-28 16:52:32.304435: I tensorflow/stream_executor/cuda/cuda_dnn.cc:377] Loaded cuDNN version 8302
# 67/67 [==============================] - ETA: 0s - loss: 1.4916 - categorical_accuracy: 0.4495
# Epoch 00001: val_loss improved from inf to 4.91692, saving model to model_conv3D_6_2023-08-2816_51_10.362060/model-00001-1.49156-0.44947-4.91692-0.16000.h5
# 67/67 [==============================] - 171s 3s/step - loss: 1.4916 - categorical_accuracy: 0.4495 - val_loss: 4.9169 - val_categorical_accuracy: 0.1600 - lr: 0.0010
# Epoch 2/25
# 67/67 [==============================] - ETA: 0s - loss: 1.1291 - categorical_accuracy: 0.5641
# Epoch 00002: val_loss did not improve from 4.91692
# 67/67 [==============================] - 157s 2s/step - loss: 1.1291 - categorical_accuracy: 0.5641 - val_loss: 7.9069 - val_categorical_accuracy: 0.1500 - lr: 0.0010
# Epoch 3/25
# 67/67 [==============================] - ETA: 0s - loss: 0.9938 - categorical_accuracy: 0.6335
# Epoch 00003: val_loss did not improve from 4.91692
# 67/67 [==============================] - 156s 2s/step - loss: 0.9938 - categorical_accuracy: 0.6335 - val_loss: 11.4103 - val_categorical_accuracy: 0.1500 - lr: 0.0010
# Epoch 4/25
# 67/67 [==============================] - ETA: 0s - loss: 0.7800 - categorical_accuracy: 0.6878
# Epoch 00004: val_loss did not improve from 4.91692
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 67/67 [==============================] - 156s 2s/step - loss: 0.7800 - categorical_accuracy: 0.6878 - val_loss: 5.4066 - val_categorical_accuracy: 0.2700 - lr: 0.0010
# Epoch 5/25
# 67/67 [==============================] - ETA: 0s - loss: 0.6035 - categorical_accuracy: 0.7828
# Epoch 00005: val_loss improved from 4.91692 to 4.00014, saving model to model_conv3D_6_2023-08-2816_51_10.362060/model-00005-0.60347-0.78281-4.00014-0.28000.h5
# 67/67 [==============================] - 155s 2s/step - loss: 0.6035 - categorical_accuracy: 0.7828 - val_loss: 4.0001 - val_categorical_accuracy: 0.2800 - lr: 1.0000e-04
# Epoch 6/25
# 67/67 [==============================] - ETA: 0s - loss: 0.5675 - categorical_accuracy: 0.7813
# Epoch 00006: val_loss improved from 4.00014 to 3.19170, saving model to model_conv3D_6_2023-08-2816_51_10.362060/model-
25
# 67/67 [==============================] - ETA: 0s - loss: 0.2589 - categorical_accuracy: 0.9110
# Epoch 00017: val_loss did not improve from 0.64960
# 67/67 [==============================] - 153s 2s/step - loss: 0.2589 - categorical_accuracy: 0.9110 - val_loss: 0.8120 - val_categorical_accuracy: 0.7100 - lr: 1.0000e-04
# Epoch 18/25
# 67/67 [==============================] - ETA: 0s - loss: 0.2273 - categorical_accuracy: 0.9125
# Epoch 00018: val_loss did not improve from 0.64960
# 67/67 [==============================] - 153s 2s/step - loss: 0.2273 - categorical_accuracy: 0.9125 - val_loss: 0.6962 - val_categorical_accuracy: 0.7600 - lr: 1.0000e-04
# Epoch 19/25
# 67/67 [==============================] - ETA: 0s - loss: 0.2672 - categorical_accuracy: 0.9005
# Epoch 00019: val_loss did not improve from 0.64960
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0001.
# 67/67 [==============================] - 155s 2s/step - loss: 0.2672 - categorical_accuracy: 0.9005 - val_loss: 0.7701 - val_categorical_accuracy: 0.7300 - lr: 1.0000e-04
# Epoch 20/25
# 67/67 [==============================] - ETA: 0s - loss: 0.2837 - categorical_accuracy: 0.8944
# Epoch 00020: val_loss did not improve from 0.64960
# 67/67 [==============================] - 154s 2s/step - loss: 0.2837 - categorical_accuracy: 0.8944 - val_loss: 0.6917 - val_categorical_accuracy: 0.7900 - lr: 1.0000e-04
# Epoch 21/25
# 67/67 [==============================] - ETA: 0s - loss: 0.1768 - categorical_accuracy: 0.9502
# Epoch 00021: val_loss did not improve from 0.64960
# 67/67 [==============================] - 156s 2s/step - loss: 0.1768 - categorical_accuracy: 0.9502 - val_loss: 0.7031 - val_categorical_accuracy: 0.7700 - lr: 1.0000e-04
# Epoch 22/25
# 67/67 [==============================] - ETA: 0s - loss: 0.1843 - categorical_accuracy: 0.9397
# Epoch 00022: val_loss improved from 0.64960 to 0.64278, saving model to model_conv3D_6_2023-08-2816_51_10.362060/model-00022-0.18432-0.93967-0.64278-0.78000.h5
# 67/67 [==============================] - 156s 2s/step - loss: 0.1843 - categorical_accuracy: 0.9397 - val_loss: 0.6428 - val_categorical_accuracy: 0.7800 - lr: 1.0000e-04
# Epoch 23/25
# 67/67 [==============================] - ETA: 0s - loss: 0.2432 - categorical_accuracy: 0.9276
# Epoch 00023: val_loss did not improve from 0.64278
# 67/67 [==============================] - 152s 2s/step - loss: 0.2432 - categorical_accuracy: 0.9276 - val_loss: 0.8899 - val_categorical_accuracy: 0.7200 - lr: 1.0000e-04
# Epoch 24/25
# 67/67 [==============================] - ETA: 0s - loss: 0.1779 - categorical_accuracy: 0.9502
# Epoch 00024: val_loss improved from 0.64278 to 0.62921, saving model to model_conv3D_6_2023-08-2816_51_10.362060/model-00024-0.17787-0.95023-0.62921-0.81000.h5
# 67/67 [==============================] - 154s 2s/step - loss: 0.1779 - categorical_accuracy: 0.9502 - val_loss: 0.6292 - val_categorical_accuracy: 0.8100 - lr: 1.0000e-04
# Epoch 25/25
# 67/67 [==============================] - ETA: 0s - loss: 0.1971 - categorical_accuracy: 0.9397
# Epoch 00025: val_loss did not improve from 0.62921
# 67/67 [==============================] - 154s 2s/step - loss: 0.1971 - categorical_accuracy: 0.9397 - val_loss: 0.8440 - val_categorical_accuracy: 0.7800 - lr: 1.0000e-04

# %%
plot_loss_accuracy(history)
# Out:
# dict_keys(['loss', 'categorical_accuracy', 'val_loss', 'val_categorical_accuracy', 'lr'])

# %% [markdown]
# #### Model 6: Conv 3D Model with 20 frames per video (32, 64, 128, 256) filters conv 3D layers + 128 dense layer + 128 dense layer + image size 120 by 120)

# %%
num_epochs = 25 # choose the number of epochs
print ('# epochs =', num_epochs)
batch_size = 20  #experiment with the batch size
print ('# batch size =', batch_size)
num_frames = 20
print ('# num_frames per video =', num_frames)
height = 120
width = 120

conv_filters = (32, 64, 128, 256)
dense_filters = (128, 128)
model = conv3D(conv_filters=conv_filters,dense_nodes=dense_filters, num_images=num_frames)
print (model.summary())
# Out:
# # epochs = 25
# # batch size = 20
# # num_frames per video = 20
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_8 (Conv3D)           (None, 20, 120, 120, 32)  2624
#
#  activation_14 (Activation)  (None, 20, 120, 120, 32)  0
#
#  batch_normalization_12 (Bat  (None, 20, 120, 120, 32)  128
#  chNormalization)
#
#  max_pooling3d_8 (MaxPooling  (None, 10, 60, 60, 32)   0
#  3D)
#
#  conv3d_9 (Conv3D)           (None, 10, 60, 60, 64)    55360
#
#  activation_15 (Activation)  (None, 10, 60, 60, 64)    0
#
#  batch_normalization_13 (Bat  (None, 10, 60, 60, 64)   256
#  chNormalization)
#
#  max_pooling3d_9 (MaxPooling  (None, 5, 30, 30, 64)    0
#  3D)
#
#  conv3d_10 (Conv3D)          (None, 5, 30, 30, 128)    221312
#
#  activation_16 (Activation)  (None, 5, 30, 30, 128)    0
#
#  batch_normalization_14 (Bat  (None, 5, 30, 30, 128)   512
#  chNormalization)
#
#  max_pooling3d_10 (MaxPoolin  (None, 2, 15, 15, 128)   0
#  g3D)
#
#  conv3d_11 (Conv3D)          (None, 2, 15, 15, 256)    884992
#
#  activation_17 (Activation)  (None, 2, 15, 15, 256)    0
#
#  batch_normalization_15 (Bat  (None, 2, 15, 15, 256)   1024
#  chNormalization)
#
#  max_pooling3d_11 (MaxPoolin  (None, 1, 7, 7,
accuracy: 0.8500 - lr: 1.0000e-04
# Epoch 25/25
# 34/34 [==============================] - ETA: 0s - loss: 0.0857 - categorical_accuracy: 0.9834
# Epoch 00025: val_loss improved from 0.48592 to 0.44718, saving model to model_conv3D_8_2023-08-2907_28_23.340432/model-00025-0.08569-0.98341-0.44718-0.84000.h5
# 34/34 [==============================] - 111s 3s/step - loss: 0.0857 - categorical_accuracy: 0.9834 - val_loss: 0.4472 - val_categorical_accuracy: 0.8400 - lr: 1.0000e-04

# %%
plot_loss_accuracy(history)
# Out:
# dict_keys(['loss', 'categorical_accuracy', 'val_loss', 'val_categorical_accuracy', 'lr'])

# %% [markdown]
# #### Model 7: Conv 3D Model with 30 frames per video and a 5 by 5 filter size (16, 32, 64, 128 filters conv 3D layers + 256 dense layer + 128 dense layer + image size 120 by 120)

# %%
#write your model here
def conv3D_5by5(conv_filters=(16, 32, 64, 128), dense_nodes=(256,128), dropout=0.25, num_images=20, height=120, width=120):

    model = Sequential()

    model.add(Conv3D(conv_filters[0], (5, 5, 5), padding='same', input_shape=(num_images, height, width, 3)))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling3D(pool_size=(2, 2, 2)))

    model.add(Conv3D(conv_filters[1], (3, 3, 3), padding='same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling3D(pool_size=(2, 2, 2)))
    
    model.add(Conv3D(conv_filters[2], (3, 3, 3), padding='same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling3D(pool_size=(2, 2, 2)))
    
    model.add(Conv3D(conv_filters[3], (3, 3, 3), padding='same'))    
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling3D(pool_size=(2, 2, 2)))
    
    model.add(Flatten())
    model.add(Dense(dense_nodes[0]))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(Dropout(dropout))

    model.add(Dense(dense_nodes[1]))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(Dropout(dropout))

    model.add(Dense(num_classes))
    model.add(Activation('softmax'))

    opt = tf.keras.optimizers.Adam() #write your optimizer
    model.compile(opt, loss='categorical_crossentropy', metrics=['categorical_accuracy'])    
    
    return model

# %%
num_epochs = 15 # choose the number of epochs
print ('# epochs =', num_epochs)
batch_size = 5  #experiment with the batch size
print ('# batch size =', batch_size)
num_frames = 30
print ('# num_frames per video =', num_frames)
height = 120
width = 120

model = conv3D_5by5(num_images=num_frames)

print (model.summary())
# Out:
# # epochs = 15
# # batch size = 5
# # num_frames per video = 30
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_20 (Conv3D)          (None, 30, 120, 120, 16)  6016
#
#  activation_35 (Activation)  (None, 30, 120, 120, 16)  0
#
#  batch_normalization_30 (Bat  (None, 30, 120, 120, 16)  64
#  chNormalization)
#
#  max_pooling3d_20 (MaxPoolin  (None, 15, 60, 60, 16)   0
#  g3D)
#
#  conv3d_21 (Conv3D)          (None, 15, 60, 60, 32)    13856
#
#  activation_36 (Activation)  (None, 15, 60, 60, 32)    0
#
#  batch_normalization_31 (Bat  (None, 15, 60, 60, 32)   128
#  chNormalization)
#
#  max_pooling3d_21 (MaxPoolin  (None, 7, 30, 30, 32)    0
#  g3D)
#
#  conv3d_22 (Conv3D)          (None, 7, 30, 30, 64)     55360
#
#  activation_37 (Activation)  (None, 7, 30, 30, 64)     0
#
#  batch_normalization_32 (Bat  (None, 7, 30, 30, 64)    256
#  chNormalization)
#
#  max_pooling3d_22 (MaxPoolin  (None, 3, 15, 15, 64)    0
#  g3D)
#
#  conv3d_23 (Conv3D)          (None, 3, 15, 15, 128)    221312
#
#  activation_38 (Activation)  (None, 3, 15, 15, 128)    0
#
#  batch_normalization_33 (Bat  (None, 3, 15, 15, 128)   512
#  chNormalization)
#
#  max_pooling3d_23 (MaxPoolin  (None, 1, 7, 7, 128)     0
#  g3D)
#
#  flatten_5 (Flatten)         (None, 6272)              0
#
#  dense_15 (Dense)            (None, 256)               1605888
#
#  activation_39 (Activation)  (None, 256)               0
#
#  batch_normalization_34 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_10 (Dropout)        (None, 256)               0
#
#  dense_16 (Dense)            (None, 128)               32896
#
#  activation_40 (Activation)  (None, 128)               0
#
#  batch_normalization_35 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_11 (Dropout)        (None, 128)               0
#
#  dense_17 (Dense)            (None, 5)                 645
#
#  activation_41 (Activation)  (None, 5)                 0
#
# =================================================================
# Total params: 1,938,469
# Trainable params: 1,937,221
# Non-trainable params: 1,248
# _________________________________________________________________
# None

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit_generator` to decide the number of next() calls it need to make.
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %%
callbacks_list = model_callbacks("model_conv3D_9")

steps_per_epoch, validation_steps = calculate_steps(num_train_sequences, num_val_sequences, batch_size)

train_generator = generate(train_path, train_doc, batch_size, num_images=num_frames)

val_generator   = generate(val_path, val_doc, batch_size, num_images=num_frames)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                              callbacks=callbacks_list, validation_data=val_generator, 
                              validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Epoch 1/15
# 133/133 [==============================] - ETA: 0s - loss: 1.7426 - categorical_accuracy: 0.3575
# Epoch 00001: val_loss improved from inf to 9.84336, saving model to model_conv3D_9_2023-08-2907_28_23.340432/model-00001-1.74264-0.35747-9.84336-0.15000.h5
# 133/133 [==============================] - 166s 1s/step - loss: 1.7426 - categorical_accuracy: 0.3575 - val_loss: 9.8434 - val_categorical_accuracy: 0.1500 - lr: 0.0010
# Epoch 2/15
# 133/133 [==============================] - ETA: 0s - loss: 1.4055 - categorical_accuracy: 0.4449
# Epoch 00002: val_loss improved from 9.84336 to 3.31989, saving model to model_conv3D_9_2023-08-2907_28_23.340432/model-00002-1.40553-0.44495-3.31989-0.27000.h5
# 133/133 [==============================] - 164s 1s/step - loss: 1.4055 - categorical_accuracy: 0.4449 - val_loss: 3.3199 - val_categorical_accuracy: 0.2700 - lr: 0.0010
# Epoch 3/15
# 133/133 [==============================] - ETA: 0s - loss: 1.3764 - categorical_accuracy: 0.4615
# Epoch 00003: val_loss improved from 3.31989 to 1.45191, saving model to model_conv3D_9_2023-08-2907_28_23.340432/model-00003-1.37643-0.46154-1.45191-0.45000.h5
# 133/133 [==============================] - 163s 1s/step - loss: 1.3764 - categorical_accuracy: 0.4615 - val_loss: 1.4519 - val_categorical_accuracy: 0.4500 - lr: 0.0010
# Epoch 4/15
# 133/133 [==============================] - ETA: 0s - loss: 1.2662 - categorical_accuracy: 0.5098
# Epoch 00004: val_loss did not improve from 1.45191
# 133/133 [==============================] - 162s 1s/step - loss: 1.2662 - categorical_accuracy: 0.5098 - val_loss: 3.5605 - val_categorical_accuracy: 0.1800 - lr: 0.0010
# Epoch
accuracy: 0.6500 - lr: 1.0000e-04
# Epoch 15/15
# 133/133 [==============================] - ETA: 0s - loss: 0.6610 - categorical_accuracy: 0.7466
# Epoch 00015: val_loss did not improve from 0.44703
# 133/133 [==============================] - 158s 1s/step - loss: 0.6610 - categorical_accuracy: 0.7466 - val_loss: 0.4644 - val_categorical_accuracy: 0.8200 - lr: 1.0000e-04

# %%
plot_loss_accuracy(history)
# Out:
# dict_keys(['loss', 'categorical_accuracy', 'val_loss', 'val_categorical_accuracy', 'lr'])

# %% [markdown]
# ### TRANSFER LEARNING - MobileNet Conv2d + GRU

# %%
from keras.applications import mobilenet

def mobilenet_RNN(fine_tune=False, gru=False, lstm_gru_cells=128, dense_nodes=128, dropout=0.25, num_images=20, height=120, width=120):

    mobilenet_transfer = mobilenet.MobileNet(weights='imagenet', include_top=False)
    print("Number of layers in the pretrained mobilenet model: ", len(mobilenet_transfer.layers))

    if (fine_tune):
        # Fine-tune from this layer onwards
        fine_tune_at = 50
        # Freeze all the layers before the `fine_tune_at` layer
        for layer in mobilenet_transfer.layers[:fine_tune_at]:
            layer.trainable = False

    model = Sequential()
    model.add(TimeDistributed(mobilenet_transfer,input_shape=(num_images, height, width, 3)))
    model.add(TimeDistributed(BatchNormalization()))
    model.add(TimeDistributed(MaxPooling2D((2, 2))))
    model.add(TimeDistributed(Flatten()))
    if (gru):
        model.add(GRU(lstm_gru_cells))
    else:
        model.add(LSTM(lstm_gru_cells))
    model.add(Dropout(dropout))
    model.add(Dense(dense_nodes, activation='relu'))
    model.add(Dropout(dropout))
    model.add(Dense(num_classes, activation='softmax'))

    opt = tf.keras.optimizers.Adam() #write your optimizer
    model.compile(opt, loss='categorical_crossentropy', metrics=['categorical_accuracy'])    
    return model

# %% [markdown]
# #### Model 8: Mobilenet (re train all weights) + GRU (128 cells) + 128 dense nodes

# %%
num_epochs = 20 # choose the number of epochs
print ('# epochs =', num_epochs)
batch_size = 10  #experiment with the batch size
print ('# batch size =', batch_size)
num_frames = 20
print ('# num frames per video =', num_frames)
height = 120
width = 120

model = mobilenet_RNN(num_images=num_frames, gru=True)
print (model.summary())
# Out:
# # epochs = 20
# # batch size = 10
# # num frames per video = 20
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Number of layers in the pretrained mobilenet model:  86
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed (TimeDistr  (None, 20, 3, 3, 1024)   3228864
#  ibuted)
#
#  time_distributed_1 (TimeDis  (None, 20, 3, 3, 1024)   4096
#  tributed)
#
#  time_distributed_2 (TimeDis  (None, 20, 1, 1, 1024)   0
#  tributed)
#
#  time_distributed_3 (TimeDis  (None, 20, 1024)         0
#  tributed)
#
#  gru (GRU)                   (None, 128)               443136
#
#  dropout_12 (Dropout)        (None, 128)               0
#
#  dense_18 (Dense)            (None, 128)               16512
#
#  dropout_13 (Dropout)        (None, 128)               0
#
#  dense_19 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 3,693,253
# Trainable params: 3,669,317
# Non-trainable params: 23,936
# _________________________________________________________________
# None

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit_generator` to decide the number of next() calls it need to make.
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %%
callbacks_list = model_callbacks("model_retrain_mobilenet_gru")

steps_per_epoch, validation_steps = calculate_steps(num_train_sequences, num_val_sequences, batch_size)

train_generator = generate(train_path, train_doc, batch_size, num_images=num_frames)

val_generator   = generate(val_path, val_doc, batch_size, num_images=num_frames)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                              callbacks=callbacks_list, validation_data=val_generator, 
                              validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Epoch 1/20
# 67/67 [==============================] - ETA: 0s - loss: 0.8684 - categorical_accuracy: 0.6817
# Epoch 00001: val_loss improved from inf to 0.73860, saving model to model_retrain_mobilenet_gru_2023-08-2907_28_23.340432/model-00001-0.86838-0.68175-0.73860-0.70000.h5
# 67/67 [==============================] - 115s 2s/step - loss: 0.8684 - categorical_accuracy: 0.6817 - val_loss: 0.7386 - val_categorical_accuracy: 0.7000 - lr: 0.0010
# Epoch 2/20
# 67/67 [==============================] - ETA: 0s - loss: 0.2497 - categorical_accuracy: 0.9261
# Epoch 00002: val_loss improved from 0.73860 to 0.27647, saving model to model_retrain_mobilenet_gru_2023-08-2907_28_23.340432/model-00002-0.24975-0.92609-0.27647-0.89000.h5
# 67/67 [==============================] - 112s 2s/step - loss: 0.2497 - categorical_accuracy: 0.9261 - val_loss: 0.2765 - val_categorical_accuracy: 0.8900 - lr: 0.0010
# Epoch 3/20
# 67/67 [==============================] - ETA: 0s - loss: 0.2176 - categorical_accuracy: 0.9397
# Epoch 00003: val_loss improved from 0.27647 to 0.20935, saving model to model_retrain_mobilenet_gru_2023-08-2907_28_23.340432/model-00003-0.21755-0.93967-0.20935-0.88000.h5
# 67/67 [==============================] - 109s 2s/step - loss: 0.2176 - categorical_accuracy: 0.9397 - val_loss: 0.2094 - val_categorical_accuracy: 0.8800 - lr: 0.0010
# Epoch 4/20
# 67/67 [==============================] - ETA: 0s - loss: 0.1917 - categorical_accuracy: 0.9532
# Epoch 00004: val_loss did not improve from 0.20935
# 67/67 [==============================] - 109s 2s/step - loss: 0.1917 - categorical_accuracy: 0.9532 - val_loss: 0.2642 - val_categorical_accuracy: 0.9200 - lr: 0.0010
# Epoch 5/20
# 67/67 [==============================] - ETA: 0s - loss: 0.
accuracy: 0.9900 - lr: 1.0000e-04
# Epoch 20/20
# 67/67 [==============================] - ETA: 0s - loss: 0.0178 - categorical_accuracy: 0.9970
# Epoch 00020: val_loss did not improve from 0.01333
# 67/67 [==============================] - 117s 2s/step - loss: 0.0178 - categorical_accuracy: 0.9970 - val_loss: 0.0465 - val_categorical_accuracy: 0.9900 - lr: 1.0000e-04

# %%
plot_loss_accuracy(history)
# Out:
# dict_keys(['loss', 'categorical_accuracy', 'val_loss', 'val_categorical_accuracy', 'lr'])

# %% [markdown]
# #### Model 9: Mobilenet (re train all weights) + GRU (128 cells) + 128 dense nodes + Random data transformations on training data set

# %%
num_epochs = 15 # choose the number of epochs
print ('# epochs =', num_epochs)
batch_size = 10  #experiment with the batch size
print ('# batch size =', batch_size)
num_frames = 30
print ('# num frames per video =', num_frames)
height = 120
width = 120

model = mobilenet_RNN(gru=True, num_images=num_frames)
print(model.summary())
# Out:
# # epochs = 15
# # batch size = 10
# # num frames per video = 30
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Number of layers in the pretrained mobilenet model:  86
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed_4 (TimeDis  (None, 30, 3, 3, 1024)   3228864
#  tributed)
#
#  time_distributed_5 (TimeDis  (None, 30, 3, 3, 1024)   4096
#  tributed)
#
#  time_distributed_6 (TimeDis  (None, 30, 1, 1, 1024)   0
#  tributed)
#
#  time_distributed_7 (TimeDis  (None, 30, 1024)         0
#  tributed)
#
#  gru_1 (GRU)                 (None, 128)               443136
#
#  dropout_14 (Dropout)        (None, 128)               0
#
#  dense_20 (Dense)            (None, 128)               16512
#
#  dropout_15 (Dropout)        (None, 128)               0
#
#  dense_21 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 3,693,253
# Trainable params: 3,669,317
# Non-trainable params: 23,936
# _________________________________________________________________
# None

# %%
callbacks_list = model_callbacks("model_retrain_mobilenet_gru")

steps_per_epoch, validation_steps = calculate_steps(num_train_sequences, num_val_sequences, batch_size)

train_generator = generate(train_path, train_doc, batch_size, augment=True, num_images=num_frames)

val_generator   = generate(val_path, val_doc, batch_size, num_images=num_frames)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                              callbacks=callbacks_list, validation_data=val_generator, 
                              validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Epoch 1/15
# 67/67 [==============================] - ETA: 0s - loss: 0.9975 - categorical_accuracy: 0.6154
# Epoch 00001: val_loss improved from inf to 0.75179, saving model to model_retrain_mobilenet_gru_2023-08-2907_28_23.340432/model-00001-0.99746-0.61538-0.75179-0.73000.h5
# 67/67 [==============================] - 198s 3s/step - loss: 0.9975 - categorical_accuracy: 0.6154 - val_loss: 0.7518 - val_categorical_accuracy: 0.7300 - lr: 0.0010
# Epoch 2/15
# 67/67 [==============================] - ETA: 0s - loss: 0.3599 - categorical_accuracy: 0.8824
# Epoch 00002: val_loss improved from 0.75179 to 0.40959, saving model to model_retrain_mobilenet_gru_2023-08-2907_28_23.340432/model-00002-0.35987-0.88235-0.40959-0.83000.h5
# 67/67 [==============================] - 188s 3s/step - loss: 0.3599 - categorical_accuracy: 0.8824 - val_loss: 0.4096 - val_categorical_accuracy: 0.8300 - lr: 0.0010
# Epoch 3/15
# 67/67 [==============================] - ETA: 0s - loss: 0.3315 - categorical_accuracy: 0.9005
# Epoch 00003: val_loss did not improve from 0.40959
# 67/67 [==============================] - 190s 3s/step - loss: 0.3315 - categorical_accuracy: 0.9005 - val_loss: 0.5426 - val_categorical_accuracy: 0.8200 - lr: 0.0010
# Epoch 4/15
# 67/67 [==============================] - ETA: 0s - loss: 0.3161 - categorical_accuracy: 0.9020
# Epoch 00004: val_loss did not improve from 0.40959
# 67/67 [==============================] - 184s 3s/step - loss: 0.3161 - categorical_accuracy: 0.9020 - val_loss: 0.8781 - val_categorical_accuracy: 0.7400 - lr: 0.0010
# Epoch 5/15
# 67/67 [==============================] - ETA: 0s - loss: 0.2167 - categorical_accuracy: 0.9427
# Epoch 00005: val_loss improved from 0.40959 to 0.21287, saving model to model_retrain_mobilenet_gru_2023-08-2907_28_23.340432/model-00005-0.21668-0.94268-0.21287-0.91000.h5
# 67/67 [==============================] - 188s 3s/step - loss: 0.2167 - categorical_accuracy: 0.9427 - val_loss: 0.2129 - val_categorical_accuracy: 0.9100 - lr: 0.0010
# Epoch 6/15
# 67/67 [==============================] - ETA: 0s - loss: 0.1647 - categorical_accuracy: 0.9502
# Epoch 00006: val_loss improved from 0.21287 to 0.05735, saving model to model_retrain_mobilenet_gru_2023-08-2907_28_23.340432/model-00006-0.16470-0.95023-0.05735-0.99000.h5
# 67/67 [==============================] - 187s 3s/step - loss: 0.1647 - categorical_accuracy: 0.9502 - val_loss: 0.0573 - val_categorical_accuracy: 0.9900 - lr: 0.0010
# Epoch 7/15
# 67/67 [==============================] - ETA: 0s - loss: 0.1132 - categorical_accuracy: 0.9623
# Epoch 00007: val_loss did not improve from 0.05735
# 67/67 [==============================] - 189s 3s/step - loss: 0.1132 - categorical_accuracy: 0.9623 - val_loss: 0.1777 - val_categorical_accuracy: 0.9400 - lr: 0.0010
# Epoch 8/15
# 67/67 [==============================] - ETA: 0s - loss: 0.1086 - categorical_accuracy: 0.9668
# Epoch 00008: val_loss did not improve from 0.05735
# 67/67 [==============================] - 188s 3s/step - loss: 0.1086 - categorical_accuracy: 0.9668 - val_loss: 0.2406 - val_categorical_accuracy: 0.9300 - lr: 0.0010
# Epoch 9/15
# 67/67 [==============================] - ETA: 0s - loss: 0.1891 - categorical_accuracy: 0.9472
# Epoch 00009: val_loss did not improve from 0.05735
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 67/67 [==============================] - 202s 3s/step - loss: 0.1891 - categorical_accuracy: 0.9472 - val_loss: 0.1004 - val_categorical_accuracy: 0.9800 - lr: 0.0010
# Epoch 10/15
# 67/67 [==============================] - ETA: 0s - loss: 0.0629 - categorical_accuracy: 0.9864
# Epoch 00010: val_loss did not improve from 0.05735
# 67/67 [==============================] - 208s 3s/step - loss: 0.0629 - categorical_accuracy: 0.9864 - val_loss: 0.0777 - val_categorical_accuracy: 0.9900 - lr: 1.0000e-04
# Epoch 11/15
# 67/67 [==============================] - ETA: 0s - loss: 0.0649 - categorical_accuracy: 0.9804
# Epoch 00011: val_loss did not improve from 0.05735
# 67/67 [==============================] - 205s 3s/step - loss: 0.0649 - categorical_accuracy: 0.9804 - val_loss: 0.0597 - val_categorical_accuracy: 0.9900 - lr: 1.0000e-04
# Epoch 12/15
# 67/67 [==============================] - ETA: 0s - loss: 0.0550 - categorical_accuracy: 0.9834
# Epoch 00012: val_loss did not improve from 0.05735
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.0001.
# 67/67 [==============================] - 208s 3s/step - loss: 0.0550 - categorical_accuracy: 0.9834 - val_loss: 0.0639 - val_categorical_accuracy: 0.9800 - lr: 1.0000e-04
# Epoch 13/15
# 67/67 [==============================] - ETA: 0s - loss: 0.0316 - categorical_accuracy: 0.9955
# Epoch 00013: val_loss did not improve from 0.05735
# 67/67 [==============================] - 198s 3s/step - loss: 0.0316 - categorical_accuracy: 0.9955 - val_loss: 0.0947 - val_categorical_accuracy: 0.9800 - lr: 1.0000e-04
# Epoch 14/15
# 67/67 [==============================] - ETA: 0s - loss: 0.0390 - categorical_accuracy: 0.9894
# Epoch 00014: val_loss improved from 0.05735 to 0.05449, saving model to model_retrain_mobilenet_gru_2023-08-2907_28_23.340432/model-00014-0.03903-0.98944-0.05449-0.99000.h5
# 67/67 [==============================] - 187s 3s/step - loss: 0.0390 - categorical_accuracy: 0.9894 - val_loss: 0.0545 - val_categorical_accuracy: 0.9900 - lr: 1.0000e-04
# Epoch 15/15
# 67/67 [==============================] - ETA: 0s - loss: 0.0226 - categorical_accuracy: 0.9925
# Epoch 00015: val_loss improved from 0.05449 to 0.01405, saving model to model_retrain_mobilenet_gru_2023-08-2907_28_23.340432/model-00015-0.02262-0.99246-0.01405-1.00000.h5
# 67/67 [==============================] - 187s 3s/step - loss: 0.0226 - categorical_accuracy: 0.9925 - val_loss: 0.0140 - val_categorical_accuracy: 1.0000 - lr: 1.0000e-04

# %%
plot_loss_accuracy(history)
# Out:
# dict_keys(['loss', 'categorical_accuracy', 'val_loss', 'val_categorical_accuracy', 'lr'])

# %% [markdown]
# #### Model 10: Mobilenet (re train all wieghts) + LSTM (128 cells) + 128 dense nodes

# %%
num_epochs = 15 # choose the number of epochs
print ('# epochs =', num_epochs)
batch_size = 10  #experiment with the batch size
print ('# batch size =', batch_size)
num_frames = 20
print ('# num frames per video =', num_frames)
height = 120
width = 120

model = mobilenet_RNN(fine_tune=False, gru=False, num_images=num_frames)
print(model.summary())
# Out:
# # epochs = 15
# # batch size = 10
# # num frames per video = 20
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Number of layers in the pretrained mobilenet model:  86
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed_12 (TimeDi  (None, 20, 3, 3, 1024)   3228864
#  stributed)
#
#  time_distributed_13 (TimeDi  (None, 20, 3, 3, 1024)   4096
#  stributed)
#
#  time_distributed_14 (TimeDi  (None, 20, 1, 1, 1024)   0
#  stributed)
#
#  time_distributed_15 (TimeDi  (None, 20, 1024)         0
#  stributed)
#
#  lstm_1 (LSTM)               (None, 128)               590336
#
#  dropout_18 (Dropout)        (None, 128)               0
#
#  dense_24 (Dense)            (None, 128)               16512
#
#  dropout_19 (Dropout)        (None, 128)               0
#
#  dense_25 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 3,840,453
# Trainable params: 3,816,517
# Non-trainable params: 23,936
# _________________________________________________________________
# None

# %%
callbacks_list = model_callbacks("model_retrain_mobilenet_lstm")

steps_per_epoch, validation_steps = calculate_steps(num_train_sequences, num_val_sequences, batch_size)

train_generator = generate(train_path, train_doc, batch_size, num_images=num_frames)

val_generator   = generate(val_path, val_doc, batch_size, num_images=num_frames)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                              callbacks=callbacks_list, validation_data=val_generator, 
                              validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Epoch 1/15
# 67/67 [==============================] - ETA: 0s - loss: 1.1077 - categorical_accuracy: 0.5234
# Epoch 00001: val_loss improved from inf to 0.67545, saving model to model_retrain_mobilenet_lstm_2023-08-2907_28_23.340432/model-00001-1.10770-0.52338-0.67545-0.78000.h5
# 67/67 [==============================] - 115s 2s/step - loss: 1.1077 - categorical_accuracy: 0.5234 - val_loss: 0.6754 - val_categorical_accuracy: 0.7800 - lr: 0.0010
# Epoch 2/15
# 67/67 [==============================] - ETA: 0s - loss: 0.4588 - categorical_accuracy: 0.8507
# Epoch 00002: val_loss improved from 0.67545 to 0.29834, saving model to model_retrain_mobilenet_lstm_2023-08-2907_28_23.340432/model-00002-0.45876-0.85068-0.29834-0.89000.h5
# 67/67 [==============================] - 110s 2s/step - loss: 0.4588 - categorical_accuracy: 0.8507 - val_loss: 0.2983 - val_categorical_accuracy: 0.8900 - lr: 0.0010
# Epoch 3/15
# 67/67 [==============================] - ETA: 0s - loss: 0.3538 - categorical_accuracy: 0.8944
# Epoch 00003: val_loss did not improve from 0.29834
# 67/67 [==============================] - 112s 2s/step - loss: 0.3538 - categorical_accuracy: 0.8944 - val_loss: 0.4512 - val_categorical_accuracy: 0.8500 - lr: 0.0010
# Epoch 4/15
# 67/67 [==============================] - ETA: 0s - loss: